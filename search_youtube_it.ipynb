# %%
from googleapiclient import discovery

api_key = 'AIzaSyDYE2mouOWowzYViSkXw2G1C5uUu0lLSeg'

# 最大50件らしい
max_results = 50

def get_videos_search(keyword):
    youtube = build('youtube', 'v3', developerKey=api_key)
    youtube_query = youtube.search().list(q=keyword, part='id,snippet', maxResults=max_results)
    youtube_res = youtube_query.execute()
    return youtube_res.get('items', [])

result = get_videos_search('大愚和尚')
for item in result:
    if item['id']['kind'] == 'youtube#video':
        print(item['snippet']['title'])
        print('https://www.youtube.com/watch?v=' + item['id']['videoId'])
# Out:
# 自分のまいた種の結果が返ってくる３つのタイミング
# https://www.youtube.com/watch?v=AAKZ2znMb0w
# コロナウィルスの影に忍び寄る新たな感染症の恐怖
# https://www.youtube.com/watch?v=bEBg9aT2XJU
# メンタルが弱い人は〇〇を決めていない。
# https://www.youtube.com/watch?v=eXw2ygiW0iI
# 自分の「心」の守り方と「強くなるため」のはじめの一歩
# https://www.youtube.com/watch?v=WerIEdMdFD4
# その苦しみは大事に持っておきなさい
# https://www.youtube.com/watch?v=pW7biqmlflM
# 宗教に優劣はあるの？正しく教えをとらえる手段
# https://www.youtube.com/watch?v=2WtWp2gGlCc
# 人生の時間を無駄にしないための、たった一つの作業。
# https://www.youtube.com/watch?v=E738fBAUNs4
# 大愚和尚は、「霊」の存在をどのようにとらえているのか
# https://www.youtube.com/watch?v=_H81PIZJNSI
# 「寝る」「自然に触れる」「触れてもらう」が心を癒す
# https://www.youtube.com/watch?v=4WgHLHF5mGA
# 「生きる意味」は他に求めず、「人生の意味づけ」は自分で行う
# https://www.youtube.com/watch?v=dO_movg3sbY
# 不倫はそんなに悪いことですか？
# https://www.youtube.com/watch?v=32bL34Vz9Rs
# 正しく生きるな！楽しく生きよ！
# https://www.youtube.com/watch?v=BpePBJpOeR0
# 「過食をやめる」という考えをやめなさい
# https://www.youtube.com/watch?v=BVbvSAps_DU
# 人の嫌なところが気になりだしたら聞く話
# https://www.youtube.com/watch?v=N4HlfoyP2rI
# ...

# %%
import pandas as pd
df = pd.read_csv("./output/youtube_output.csv")
df.head(50)
# Out:
#                                                  タイトル  \
# 0   短編映画『花束 feat. LITHIUM FEMME』 - YouTubehttps://...
# 1   「何の話をしているの」短編映画 - YouTubehttps://www.youtube.c...
# 2   【すごい！WEB動画集】短編映画「おっさん  スケボー」｜Taka ...https://n...
# 3   短編映画『半分ノ世界』メイキング動画 - YouTubehttps://www.youtub...
# 4   多分誰でもできる短編映画の作り方講座〜anagon流〜｜あなご ...https://not...
# 5   【短編ドラマ・短編映画】母の命【公式】【ファミリードラマ】 Short ...https:/...
# 6   短編映画「ぽつり、岡山」 主演：岡山天音 × 監督：前野朋哉 ...https://www....
# 7   短編動画「既読」【自主制作】 - YouTubehttps://www.youtube.co...
# 8   ショートムービー「窓の外側」 - YouTubehttps://www.youtube.co...
# 9   【短編ドラマ・短編映画】 恋愛！パジャマパーティー 【公式】【恋愛 ...https://w...
# 10  ショートショートフィルムフェスティバル ＆ アジア2015 ダイジェスト ...https:...
# 11  短編映画「まる。」予告動画 - YouTubehttps://www.youtube.com...
# 12  ピクサー人気キャラの短編映画集『ピクサー・ショート・フィルム Vol ...https://...
# 13  映像通が選ぶおすすめ短編映画・ショートムービー12選 ｜ VOKKA ...https://...
# 14  短編映画『雨女』 - YouTubehttps://www.youtube.com › watch
# 15  エイジアムービー｜短編映画・動画制作・映像制作https://asia-ina.com › ...
# ...
